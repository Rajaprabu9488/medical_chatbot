# %%
from google import genai
from PIL import Image
from dotenv import  load_dotenv
import os
load_dotenv()
# Out:
# c:\Users\My-PC\OneDrive\Desktop\medical-chatbot\env\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.1.0)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# True

# %%
API_KEY = os.getenv("OCR_API")

client = genai.Client(api_key=API_KEY)

# %%
image = Image.open("train_image/sample_2.jpeg")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[
        "Extract all text from this image and in text have decimal values like .5 change it 0.5",
        image
    ]
)

print(response.text)
# Out:
# Here is the extracted text from the image, with decimal values like `.5` changed to `0.5`:
#
# NATIONAL PHARMACY
# 111, Medical College Road - Vallam Road, Thanjavur
# Phone No: 04362-241241
#
# DL. NO: TJT/3634/20-21
# GSTIN No: 33AAIFL9408M1ZX
#
# Sales bill
# DELIVERED
#
# Bill No: 16/295833
# Date: 17/Feb/2026 01:13 AM
# Name: RAHIMA SANOFAR (Y)
# Ref.By: Dr.Self
# PHN: EPHN2016106878
# Sale Type: Cash
#
# | No | Particulars          | Batch    | Exp     | Qty | Rate | NetAmt |
# |----|----------------------|----------|---------|-----|------|--------|
# | 1  | QUTIPIN 25 TAB       | GTG3079A | 2028-09 | 15  | 7.50 | 112.50 |
# | 2  | ARPIZOL 2MG          | SIG1577A | 2027-06 | 4   | 7.78 | 31.12  |
# | 3  | ARPIZOL 2MG          | SIG1577A | 2027-06 | 11  | 7.78 | 85.59  |
# | 4  | CLONOTRIL 0.5MG TAB | 2JC6MO13 | 2028-10 | 15  | 3.68 | 55.25  |
#
# Tot items: 4
# Qty: 45
# Net Amt : Rs. 284.46
# CGST : Rs.6.77
# By Cash : Rs. 284.00
# SGST : Rs.6.77
#
# TWO HUNDRED EIGHTY FOUR RUPEES ONLY

# %%
with open("extracted_text/sample_2.txt",'+w') as file:
    file.write(response.text)
