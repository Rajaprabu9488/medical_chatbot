# %%
from itertools import zip_longest
a = ['dependent','symptoms']
b= [1,2,3,4,5]

for x,y in zip_longest(a,b):
    print(x,y)

all('dependent' in convo for convo in a)
# Out:
# dependent 1
# symptoms 2
# None 3
# None 4
# None 5
# False
